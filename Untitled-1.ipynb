# %%
import os
import base64
import json
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build

# Set the necessary scope for Gmail API
SCOPES = ['https://www.googleapis.com/auth/gmail.readonly']

def create_service():
    creds = None
    token_file = 'token.json'

    # The file token.json stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first time.
    if os.path.exists(token_file):
        creds = Credentials.from_authorized_user_file(token_file)

    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'path/to/credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)

        # Save the credentials for the next run
        with open(token_file, 'w') as token:
            token.write(creds.to_json())

    # Build the Gmail API service
    service = build('gmail', 'v1', credentials=creds)
    return service

def list_messages(service, user_id='me', label_ids=['INBOX']):
    response = service.users().messages().list(userId=user_id, labelIds=label_ids).execute()
    messages = []
    if 'messages' in response:
        messages.extend(response['messages'])
    return messages

def get_message(service, user_id='me', msg_id=''):
    message = service.users().messages().get(userId=user_id, id=msg_id).execute()
    return message

def get_attachment(service, user_id='me', msg_id='', att_id='', file_path=''):
    attachment = service.users().messages().attachments().get(
        userId=user_id, messageId=msg_id, id=att_id).execute()

    file_data = base64.urlsafe_b64decode(attachment['data'])
    with open(file_path, 'wb') as f:
        f.write(file_data)

def main():
    service = create_service()
    messages = list_messages(service)

    for msg in messages:
        message = get_message(service, msg_id=msg['id'])
        subject = next(h['value'] for h in message['payload']['headers'] if h['name'] == 'Subject')
        print(f"Subject: {subject}")

        for part in message['payload']['parts']:
            if 'filename' in part:
                filename = part['filename']
                att_id = part['body']['attachmentId']
                file_path = f"attachments/{filename}"  # Specify your desired folder path
                get_attachment(service, msg_id=msg['id'], att_id=att_id, file_path=file_path)
                print(f"Downloaded attachment: {filename}")

if __name__ == '__main__':
    main()
# Out:
# Subject: Security alert
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Untitled-1.ipynb Cell 1 line 7
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=69'>70</a>                 print(f"Downloaded attachment: {filename}")
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=71'>72</a> if __name__ == '__main__':
# ---> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=72'>73</a>     main()
#
# Untitled-1.ipynb Cell 1 line 6
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=64'>65</a> if 'filename' in part:
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=65'>66</a>     filename = part['filename']
# ...

# %%
import os
import base64
import json
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build

SCOPES = ['https://www.googleapis.com/auth/gmail.readonly']

def create_service():
    creds = None
    token_file = 'token.json'

    # The file token.json stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first time.
    if os.path.exists(token_file):
        creds = Credentials.from_authorized_user_file(token_file)

    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'path/to/credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)

        # Save the credentials for the next run
        with open(token_file, 'w') as token:
            token.write(creds.to_json())

    # Build the Gmail API service
    service = build('gmail', 'v1', credentials=creds)
    return service

def list_messages(service, user_id='me', label_ids=['INBOX']):
    response = service.users().messages().list(userId=user_id, labelIds=label_ids).execute()
    messages = []
    if 'messages' in response:
        messages.extend(response['messages'])
    return messages

def get_message(service, user_id='me', msg_id=''):
    message = service.users().messages().get(userId=user_id, id=msg_id).execute()
    return message

def get_attachment(service, user_id='me', msg_id='', part=None, file_path=''):
    if 'body' in part and 'attachmentId' in part['body']:
        attachment = service.users().messages().attachments().get(
            userId=user_id, messageId=msg_id, id=part['body']['attachmentId']).execute()
        file_data = base64.urlsafe_b64decode(attachment['data'])
        with open(file_path, 'wb') as f:
            f.write(file_data)
        print(f"Downloaded attachment: {file_path}")
    elif 'parts' in part:
        # If the part has sub-parts, iterate through them
        for sub_part in part['parts']:
            get_attachment(service, user_id=user_id, msg_id=msg_id, part=sub_part, file_path=file_path)

def main():
    service = create_service()
    messages = list_messages(service)

    for msg in messages:
        message = get_message(service, msg_id=msg['id'])
        subject = next(h['value'] for h in message['payload']['headers'] if h['name'] == 'Subject')
        print(f"Subject: {subject}")

        for part in message['payload']['parts']:
            if 'filename' in part:
                filename = part['filename']
                file_path = f"attachments/{filename}"  # Specify your desired folder path

                # Create the 'attachments' folder if it doesn't exist
                os.makedirs(os.path.dirname(file_path), exist_ok=True)

                get_attachment(service, msg_id=msg['id'], part=part, file_path=file_path)

if __name__ == '__main__':
    main()
# Out:
# Subject: Security alert
# Subject: AITT December 2023 ED/Practical Hall Ticket- R210809213151
# Downloaded attachment: attachments/HallTicket_R210809213151.pdf
# Subject: AITT December 2023 ED/Practical Hall Ticket- R210809213151
# Downloaded attachment: attachments/HallTicket_R210809213151.pdf
# Subject: **Diabetes Health Report**
# Downloaded attachment: attachments/sample_report2.pdf
# Downloaded attachment: attachments/sample_report1.pdf
# Downloaded attachment: attachments/sample_report3.pdf
# Subject: Re: Diagnosis report
# Downloaded attachment: attachments/Report (1).pdf
# Subject: Diagnosis report
# Subject: medical record
# Subject: Security alert
# Subject: 2-Step Verification turned on
# Subject: Security alert
# Subject: Mukesh, finish setting up your new Google Account

# %%
import os
import base64
import json
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build

SCOPES = ['https://www.googleapis.com/auth/gmail.readonly']

def create_service():
    creds = None
    token_file = 'token.json'

    if os.path.exists(token_file):
        creds = Credentials.from_authorized_user_file(token_file)

    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'path/to/credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)

        with open(token_file, 'w') as token:
            token.write(creds.to_json())

    service = build('gmail', 'v1', credentials=creds)
    return service

def list_messages(service, user_id='me', label_ids=['INBOX']):
    response = service.users().messages().list(userId=user_id, labelIds=label_ids).execute()
    messages = []
    if 'messages' in response:
        messages.extend(response['messages'])
    return messages

def get_message(service, user_id='me', msg_id=''):
    message = service.users().messages().get(userId=user_id, id=msg_id).execute()
    return message

def get_attachment(service, user_id='me', msg_id='', part=None, file_path=''):
    if 'body' in part and 'attachmentId' in part['body']:
        attachment = service.users().messages().attachments().get(
            userId=user_id, messageId=msg_id, id=part['body']['attachmentId']).execute()
        file_data = base64.urlsafe_b64decode(attachment['data'])
        with open(file_path, 'wb') as f:
            f.write(file_data)
        print(f"Downloaded attachment: {file_path}")
    elif 'parts' in part:
        for sub_part in part['parts']:
            get_attachment(service, user_id=user_id, msg_id=msg_id, part=sub_part, file_path=file_path)

def save_message_body(message, file_path):
    # Assuming the body is in 'text/plain' format
    for part in message['payload']['parts']:
        if 'body' in part and 'data' in part['body']:
            body_data = part['body']['data']
            body_text = base64.urlsafe_b64decode(body_data).decode('utf-8')
            with open(file_path, 'w', encoding='utf-8') as file:
                file.write(f"Message Body:\n{body_text}")

def main():
    service = create_service()
    messages = list_messages(service)

    for msg in messages:
        message = get_message(service, msg_id=msg['id'])
        subject = next(h['value'] for h in message['payload']['headers'] if h['name'] == 'Subject')
        print(f"Subject: {subject}")

        # Create a folder for each email based on subject
        folder_path = f"emails/{subject}"
        os.makedirs(folder_path, exist_ok=True)

        body_file_path = os.path.join(folder_path, 'body.txt')
        save_message_body(message, body_file_path)

        for part in message['payload']['parts']:
            if 'filename' in part:
                filename = part['filename']
                attachment_file_path = os.path.join(folder_path, filename)
                get_attachment(service, msg_id=msg['id'], part=part, file_path=attachment_file_path)

if __name__ == '__main__':
    main()
# Out:
# Subject: Security alert
# Subject: AITT December 2023 ED/Practical Hall Ticket- R210809213151
# Downloaded attachment: emails/AITT December 2023 ED/Practical Hall Ticket- R210809213151/HallTicket_R210809213151.pdf
# Subject: AITT December 2023 ED/Practical Hall Ticket- R210809213151
# Downloaded attachment: emails/AITT December 2023 ED/Practical Hall Ticket- R210809213151/HallTicket_R210809213151.pdf
# Subject: **Diabetes Health Report**
# Downloaded attachment: emails/**Diabetes Health Report**/sample_report2.pdf
# Downloaded attachment: emails/**Diabetes Health Report**/sample_report1.pdf
# Downloaded attachment: emails/**Diabetes Health Report**/sample_report3.pdf
# Subject: Re: Diagnosis report
# Downloaded attachment: emails/Re: Diagnosis report/Report (1).pdf
# Subject: Diagnosis report
# Subject: medical record
# Subject: Security alert
# Subject: 2-Step Verification turned on
# Subject: Security alert
# Subject: Mukesh, finish setting up your new Google Account

# %%
import os
import base64
import json
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build

SCOPES = ['https://www.googleapis.com/auth/gmail.readonly']

def create_service():
    creds = None
    token_file = 'token.json'

    if os.path.exists(token_file):
        creds = Credentials.from_authorized_user_file(token_file)

    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'path/to/credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)

        with open(token_file, 'w') as token:
            token.write(creds.to_json())

    service = build('gmail', 'v1', credentials=creds)
    return service

def list_messages(service, user_id='me', label_ids=['INBOX']):
    response = service.users().messages().list(userId=user_id, labelIds=label_ids).execute()
    messages = []
    if 'messages' in response:
        messages.extend(response['messages'])
    return messages

def get_message(service, user_id='me', msg_id=''):
    message = service.users().messages().get(userId=user_id, id=msg_id).execute()
    return message

def get_attachment(service, user_id='me', msg_id='', part=None, file_path=''):
    if 'body' in part and 'attachmentId' in part['body']:
        attachment = service.users().messages().attachments().get(
            userId=user_id, messageId=msg_id, id=part['body']['attachmentId']).execute()
        file_data = base64.urlsafe_b64decode(attachment['data'])
        with open(file_path, 'wb') as f:
            f.write(file_data)
        print(f"Downloaded attachment: {file_path}")
    elif 'parts' in part:
        for sub_part in part['parts']:
            get_attachment(service, user_id=user_id, msg_id=msg_id, part=sub_part, file_path=file_path)

def save_message_body(message, folder_path):
    # Assuming the body is in 'text/plain' format
    timestamp = message['internalDate']
    body_file_path = os.path.join(folder_path, f"body_{timestamp}.txt")
    
    for part in message['payload']['parts']:
        if 'body' in part and 'data' in part['body']:
            body_data = part['body']['data']
            body_text = base64.urlsafe_b64decode(body_data).decode('utf-8')
            with open(body_file_path, 'w', encoding='utf-8') as file:
                file.write(f"Message Body:\n{body_text}")
    
    print(f"Saved mail body: {body_file_path}")

def main():
    service = create_service()
    messages = list_messages(service)

    for msg in messages:
        message = get_message(service, msg_id=msg['id'])
        subject = next(h['value'] for h in message['payload']['headers'] if h['name'] == 'Subject')
        print(f"Subject: {subject}")

        # Create a folder for each email based on subject
        folder_path = f"emails/{subject}"
        os.makedirs(folder_path, exist_ok=True)

        save_message_body(message, folder_path)

        for part in message['payload']['parts']:
            if 'filename' in part:
                filename = part['filename']
                attachment_file_path = os.path.join(folder_path, filename)
                get_attachment(service, msg_id=msg['id'], part=part, file_path=attachment_file_path)

if __name__ == '__main__':
    main()
# Out:
# Subject: Security alert
# Saved mail body: emails/Security alert/body_1701270978000.txt
# Subject: AITT December 2023 ED/Practical Hall Ticket- R210809213151
# Saved mail body: emails/AITT December 2023 ED/Practical Hall Ticket- R210809213151/body_1701023176000.txt
# Downloaded attachment: emails/AITT December 2023 ED/Practical Hall Ticket- R210809213151/HallTicket_R210809213151.pdf
# Subject: AITT December 2023 ED/Practical Hall Ticket- R210809213151
# Saved mail body: emails/AITT December 2023 ED/Practical Hall Ticket- R210809213151/body_1700921076000.txt
# Downloaded attachment: emails/AITT December 2023 ED/Practical Hall Ticket- R210809213151/HallTicket_R210809213151.pdf
# Subject: **Diabetes Health Report**
# Saved mail body: emails/**Diabetes Health Report**/body_1700799416000.txt
# Downloaded attachment: emails/**Diabetes Health Report**/sample_report2.pdf
# Downloaded attachment: emails/**Diabetes Health Report**/sample_report1.pdf
# ...

# %%
import os
import base64
import json
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build

SCOPES = ['https://www.googleapis.com/auth/gmail.readonly']

def create_service():
    creds = None
    token_file = 'token.json'

    if os.path.exists(token_file):
        creds = Credentials.from_authorized_user_file(token_file)

    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'path/to/credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)

        with open(token_file, 'w') as token:
            token.write(creds.to_json())

    service = build('gmail', 'v1', credentials=creds)
    return service

def list_messages(service, user_id='me', label_ids=['INBOX']):
    response = service.users().messages().list(userId=user_id, labelIds=label_ids).execute()
    messages = []
    if 'messages' in response:
        messages.extend(response['messages'])
    return messages

def get_message(service, user_id='me', msg_id=''):
    message = service.users().messages().get(userId=user_id, id=msg_id).execute()
    return message

def get_attachment(service, user_id='me', msg_id='', part=None, file_path=''):
    if 'body' in part and 'attachmentId' in part['body']:
        attachment = service.users().messages().attachments().get(
            userId=user_id, messageId=msg_id, id=part['body']['attachmentId']).execute()
        file_data = base64.urlsafe_b64decode(attachment['data'])
        with open(file_path, 'wb') as f:
            f.write(file_data)
        print(f"Downloaded attachment: {file_path}")
    elif 'parts' in part:
        for sub_part in part['parts']:
            get_attachment(service, user_id=user_id, msg_id=msg_id, part=sub_part, file_path=file_path)

def print_message_body(message):
    # Assuming the body is in 'text/plain' format
    for part in message['payload']['parts']:
        if 'body' in part and 'data' in part['body']:
            body_data = part['body']['data']
            body_text = base64.urlsafe_b64decode(body_data).decode('utf-8')
            print(f"Message Body:\n{body_text}")

def main():
    service = create_service()
    messages = list_messages(service)

    for msg in messages:
        message = get_message(service, msg_id=msg['id'])
        subject = next(h['value'] for h in message['payload']['headers'] if h['name'] == 'Subject')
        print(f"Subject: {subject}")

        print_message_body(message)  # Print or save the mail body content

        for part in message['payload']['parts']:
            if 'filename' in part:
                filename = part['filename']
                file_path = f"attachments/{filename}"
                os.makedirs(os.path.dirname(file_path), exist_ok=True)
                get_attachment(service, msg_id=msg['id'], part=part, file_path=file_path)

if __name__ == '__main__':
    main()
# Out:
# Subject: Security alert
# Message Body:
# [image: Google]
# A new sign-in on Linux
#
#
# mukesh992203@gmail.com
# We noticed a new sign-in to your Google Account on a Linux device. If this
# was you, you don’t need to do anything. If not, we’ll help you secure your
# account.
# Check activity
# <https://accounts.google.com/AccountChooser?Email=mukesh992203@gmail.com&continue=https://myaccount.google.com/alert/nt/1701270978924?rfn%3D325%26rfnc%3D1%26eid%3D-8399371764072279631%26et%3D0>
# You can also see security activity at
# https://myaccount.google.com/notifications
# You received this email to let you know about important changes to your
# Google Account and services.
# © 2023 Google LLC, 1600 Amphitheatre Parkway, Mountain View, CA 94043, USA
#
# Message Body:
# ...

# %%
import os
import base64
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build

SCOPES = ['https://www.googleapis.com/auth/gmail.readonly']

def create_service():
    creds = None
    token_file = 'token.json'

    if os.path.exists(token_file):
        creds = Credentials.from_authorized_user_file(token_file)

    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'path/to/credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)

        with open(token_file, 'w') as token:
            token.write(creds.to_json())

    service = build('gmail', 'v1', credentials=creds)
    return service

def list_messages(service, user_id='me', label_ids=['INBOX']):
    response = service.users().messages().list(userId=user_id, labelIds=label_ids).execute()
    messages = []
    if 'messages' in response:
        messages.extend(response['messages'])
    return messages

def get_message(service, user_id='me', msg_id=''):
    message = service.users().messages().get(userId=user_id, id=msg_id).execute()
    return message

def get_attachment(service, user_id='me', msg_id='', part=None, file_path=''):
    if 'body' in part and 'attachmentId' in part['body']:
        attachment = service.users().messages().attachments().get(
            userId=user_id, messageId=msg_id, id=part['body']['attachmentId']).execute()
        file_data = base64.urlsafe_b64decode(attachment['data'])
        with open(file_path, 'wb') as f:
            f.write(file_data)
        print(f"Downloaded attachment: {file_path}")
    elif 'parts' in part:
        for sub_part in part['parts']:
            get_attachment(service, user_id=user_id, msg_id=msg_id, part=sub_part, file_path=file_path)

def save_message_body(message, folder_path):
    # Assuming the body is in 'text/plain' format
    timestamp = message['internalDate']
    body_file_path = os.path.join(folder_path, f"body_{timestamp}.txt")
    
    for part in message['payload']['parts']:
        if 'body' in part and 'data' in part['body']:
            body_data = part['body']['data']
            body_text = base64.urlsafe_b64decode(body_data).decode('utf-8')
            with open(body_file_path, 'w', encoding='utf-8') as file:
                file.write(body_text)
    
    print(f"Saved mail body: {body_file_path}")

def main():
    service = create_service()
    messages = list_messages(service)

    for msg in messages:
        message = get_message(service, msg_id=msg['id'])
        subject = next(h['value'] for h in message['payload']['headers'] if h['name'] == 'Subject')
        print(f"Subject: {subject}")

        # Create a folder for each email based on subject
        folder_path = f"emails/{subject}"
        os.makedirs(folder_path, exist_ok=True)

        save_message_body(message, folder_path)

        for part in message['payload']['parts']:
            if 'filename' in part:
                filename = part['filename']
                attachment_file_path = os.path.join(folder_path, filename)
                get_attachment(service, msg_id=msg['id'], part=part, file_path=attachment_file_path)

if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/mukesh/Tensorflow/gmail_api/Untitled-1.ipynb Cell 10 line 8
#      <a href='vscode-notebook-cell:/home/mukesh/Tensorflow/gmail_api/Untitled-1.ipynb#X12sZmlsZQ%3D%3D?line=85'>86</a>                 get_attachment(service, msg_id=msg['id'], part=part, file_path=attachment_file_path)
#      <a href='vscode-notebook-cell:/home/mukesh/Tensorflow/gmail_api/Untitled-1.ipynb#X12sZmlsZQ%3D%3D?line=87'>88</a> if __name__ == '__main__':
# ---> <a href='vscode-notebook-cell:/home/mukesh/Tensorflow/gmail_api/Untitled-1.ipynb#X12sZmlsZQ%3D%3D?line=88'>89</a>     main()
#
# /home/mukesh/Tensorflow/gmail_api/Untitled-1.ipynb Cell 10 line 6
#      <a href='vscode-notebook-cell:/home/mukesh/Tensorflow/gmail_api/Untitled-1.ipynb#X12sZmlsZQ%3D%3D?line=66'>67</a> def main():
# ...
